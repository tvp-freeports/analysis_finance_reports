# %%
from pathlib import Path
import pstats
import io
PREFIX="L1"
SUFFIX="25-10-15_15:49:48"
filename = f"{PREFIX}@{SUFFIX}.prof"

path_profile=Path("profiles") / filename
stats=pstats.Stats(str(path_profile))

# %%
import glob

# %%
stats.sort_stats(pstats.SortKey.CUMULATIVE)

# %%
stats.print_stats(10)
# Out:
# Tue Oct 14 22:05:28 2025    profiles/S5@25-10-14_22:02:23.prof
#
#          105715565 function calls (105456361 primitive calls) in 185.288 seconds
#
#    Ordered by: cumulative time
#    List reduced from 2465 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         5    0.381    0.076  185.292   37.058 /home/giuly/Desktop/Progetti/freeports-AMUNDI/src/freeports_analysis/main.py:265(main)
#         5    2.696    0.539  184.572   36.914 /home/giuly/Desktop/Progetti/freeports-AMUNDI/src/freeports_analysis/main.py:209(_main_job)
#         5    8.514    1.703  169.354   33.871 /home/giuly/Desktop/Progetti/freeports-AMUNDI/src/freeports_analysis/main.py:62(pipeline_batch)
#        15    0.034    0.002  159.850   10.657 /home/giuly/Desktop/Progetti/freeports-AMUNDI/src/freeports_analysis/formats/algorithms/__init__.py:61(_exec_segment)
# ...

# %%
stats.print_stats(10)
# Out:
# Tue Oct 14 23:27:16 2025    profiles/L3@25-10-14_22:02:23.prof
#
#          456603955 function calls (455312916 primitive calls) in 1066.747 seconds
#
#    Ordered by: cumulative time
#    List reduced from 2509 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         8    0.514    0.064 1066.752  133.344 /home/giuly/Desktop/Progetti/freeports-AMUNDI/src/freeports_analysis/main.py:265(main)
#         8   21.894    2.737 1065.569  133.196 /home/giuly/Desktop/Progetti/freeports-AMUNDI/src/freeports_analysis/main.py:209(_main_job)
#         8   43.648    5.456  976.305  122.038 /home/giuly/Desktop/Progetti/freeports-AMUNDI/src/freeports_analysis/main.py:62(pipeline_batch)
#        24    0.176    0.007  930.895   38.787 /home/giuly/Desktop/Progetti/freeports-AMUNDI/src/freeports_analysis/formats/algorithms/__init__.py:61(_exec_segment)
# ...
